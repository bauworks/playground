# %%
import math
import sys

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("kensa.csv",encoding="SHIFT-JIS")

print(df)
# Out:
#           null  検査実施件数（日別）  新規（日別）  陰性確認（日別）  新規のうち陽性件数  検査実施件数(累計)　　  新規(累計)  \
# 0    2020/2/14           2       2         0          0             2       2
# 1    2020/2/15           0       0         0          0             2       2
# 2    2020/2/16           0       0         0          0             2       2
# 3    2020/2/17           1       1         0          0             3       3
# 4    2020/2/18           0       0         0          0             3       3
# ..         ...         ...     ...       ...        ...           ...     ...
# 212  2020/9/13          48      48         0          0         16400   15199
# 213  2020/9/14         278     278         0          7         16678   15477
# 214  2020/9/15         186     186         0          2         16864   15663
# 215  2020/9/16         120     120         0          1         16984   15783
# 216  2020/9/17          86      86         0          2         17070   15869
#
#      陰性確認(累計)  新規のうち陽性件数(累計)
# ...

# %%
df['DateIdx'] = pd.to_datetime(df['null'], format='%Y/%m/%d')
x = df['DateIdx']
y = df['新規のうち陽性件数']
plt.plot(x,y)
